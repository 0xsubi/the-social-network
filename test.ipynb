# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')

# %%
# Total number of data points
print(df.shape[0])
# Out:
# 10379587

# %%
# Total number of posts created, posts viewed, logins, logouts
post_creates = df[df['action'] == 'MAKE_POST']
post_views = df[df['action'] == 'VIEW_POST']
logins = df[df['action'] == 'LOGIN']
logouts = df[df['action'] == 'LOGIN']

# %%
print(post_creates.head(10))
# Out:
#     sl  user_id           timestamp     action
# 24  24       28 2018-01-08 23:00:36  MAKE_POST
# 34  34      115 2018-01-09 01:11:34  MAKE_POST
# 35  35      115 2018-01-09 01:11:34  MAKE_POST
# 36  36      115 2018-01-09 01:11:34  MAKE_POST
# 37  37      115 2018-01-09 01:11:34  MAKE_POST
# 38  38      115 2018-01-09 01:11:34  MAKE_POST
# 39  39      115 2018-01-09 01:11:34  MAKE_POST
# 40  40      115 2018-01-09 01:11:34  MAKE_POST
# 41  41      115 2018-01-09 01:11:34  MAKE_POST
# 42  42      115 2018-01-09 01:11:34  MAKE_POST

# %%
post_creates.set_index('timestamp',inplace=True)
post_views.set_index('timestamp',inplace=True)
logins.set_index('timestamp',inplace=True)
logouts.set_index('timestamp',inplace=True)

post_creates_by_month = post_creates.resample('M').count()
post_views_by_month = post_views.resample('M').count()
logins_by_month = logins.resample('M').count()
logouts_by_month = logouts.resample('M').count()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(post_creates_by_month.index.values,
        post_creates_by_month['action'],
        color='purple')
ax.set(xlabel="Month",
       ylabel="Posts Created",
       title="Posts Created over Months on Fakebook")
# Out:
# [Text(0.5, 0, 'Month'),
#  Text(0, 0.5, 'Posts Created'),
#  Text(0.5, 1.0, 'Posts Created vs Month on Fakebook')]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(post_views_by_month.index.values,
        post_views_by_month['action'],
        color='purple')
ax.set(xlabel="Month",
       ylabel="Posts Viewed",
       title="Posts Viewed over Months on Fakebook")
# Out:
# [Text(0.5, 0, 'Month'),
#  Text(0, 0.5, 'Posts Viewed'),
#  Text(0.5, 1.0, 'Posts Viewed over Months on Fakebook')]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(logins_by_month.index.values,
        logins_by_month['action'],
        color='purple')
ax.set(xlabel="Month",
       ylabel="Logins",
       title="Logins over Months on Fakebook")
# Out:
# [Text(0.5, 0, 'Month'),
#  Text(0, 0.5, 'Logins'),
#  Text(0.5, 1.0, 'Logins over Months on Fakebook')]

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(logouts_by_month.index.values,
        logouts_by_month['action'],
        color='purple')
ax.set(xlabel="Month",
       ylabel="Logouts",
       title="Logouts over Months on Fakebook")
# Out:
# [Text(0.5, 0, 'Month'),
#  Text(0, 0.5, 'Logouts'),
#  Text(0.5, 1.0, 'Logouts over Months on Fakebook')]
